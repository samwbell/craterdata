# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import matplotlib.gridspec as gridspec
from matplotlib.ticker import ScalarFormatter
import math
from scipy.stats.mstats import gmean
from scipy.stats import gamma, poisson, linregress, beta, norm
from scipy import optimize
from scipy import interpolate
import time
import random
import pickle as pkl
from cratrcountr import *
# %matplotlib inline

# %%
synth_area=10000
synth_age=2.0
with open('example20A.pkl', 'rb') as f:
    example20A=pkl.load(f)
ds, area = example20A, synth_area

# %%
plot_differential(ds, area, d_min=1.0, d_max=100)
