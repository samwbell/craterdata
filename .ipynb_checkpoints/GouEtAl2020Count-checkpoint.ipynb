# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from scipy.constants import G
import math
from scipy.stats.mstats import gmean
from scipy.stats import gamma,poisson,linregress,beta
from scipy import optimize
import time
import random
import pickle as pkl
from cratrcountr import *

# %%
rawd = pd.read_excel('../GouEtAl2020Data.xlsx')
ds = np.array(sorted(rawd['Diam_km'].tolist()))
area = 290

# %%
bin_width_exponent=0.25
plot_cumulative_unbinned(ds,area)
