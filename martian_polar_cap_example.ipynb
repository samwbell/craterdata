# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gamma, poisson, linregress, beta, norm, lognorm
from scipy.integrate import cumulative_trapezoid, trapezoid
import math
import time
import random
import pickle as pkl
from cratrcountr import *
# %matplotlib inline

# %%
age_rv = age_pdf(
    0, 5000, 1, pf=npf_mars, cf_inv=ncf_mars_inv
) * 1000
age_rv.plot(
    error_bar_type='median', label=True, unit='Ma'
)
age_rv.percentile(0.01)
# Out:
# np.float64(4.867347375400717)
