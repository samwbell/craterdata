# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gamma, poisson, linregress, beta, norm, lognorm
from scipy.integrate import cumulative_trapezoid, trapezoid
import math
import time
import random
import pickle as pkl
from cratrcountr import *
# %matplotlib inline

# %%
age_rv = age_pdf(
    0, 5000, 1, pf=npf_mars, cf_inv=ncf_mars_inv, kind='median'
)
age_rv.plot(
    error_bar_type='median', label=True, unit='Ga', xlim=[0, 2.0],
    color='black'
)
pfig = plt.gcf()
pfig.savefig(
    'figs/martian_polar_cap_example.pdf', bbox_inches='tight',
    transparent=True
)

# %% [markdown]
# Calculation of PDF value at 1 Martian year.

# %%
age_rv[1.88085 / 1E9] / age_rv[0]
# Out:
# 0.9999999980595868
